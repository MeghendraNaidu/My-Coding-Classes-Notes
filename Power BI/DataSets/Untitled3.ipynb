# %%
import pandas as pd
import numpy as np
d=[1,2,3,4]
data=pd.Series(d)
print(type(data))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(d)
# Out:
# [1, 2, 3, 4]

# %%
import pandas as pd
d = [1,2,3,4]
data = pd.Series(d)
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(type(data))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = {
    'name':['tharun','karthik','sagar'],
    'age':[22,25,21],
    'salary':[30000,15000,40000]
}
d = pd.DataFrame(data)
print(d)
# Out:
#       name  age  salary
# 0   tharun   22   30000
# 1  karthik   25   15000
# 2    sagar   21   40000

# %%
print(d.head(2))
# Out:
#       name  age  salary
# 0   tharun   22   30000
# 1  karthik   25   15000

# %%
print(d.tail(1))
# Out:
#     name  age  salary
# 2  sagar   21   40000

# %%
print(d.describe())
# Out:
#              age        salary
# count   3.000000      3.000000
# mean   22.666667  28333.333333
# std     2.081666  12583.057392
# min    21.000000  15000.000000
# 25%    21.500000  22500.000000
# 50%    22.000000  30000.000000
# 75%    23.500000  35000.000000
# max    25.000000  40000.000000

# %%
print(d.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes
# None

# %%
print(d.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
print(d.columns)
# Out:
# Index(['name', 'age', 'salary'], dtype='object')

# %%
d.iloc[0]
# Out:
# name      tharun
# age           22
# salary     30000
# Name: 0, dtype: object

# %%
d.loc[1]
# Out:
# name      karthik
# age            25
# salary      15000
# Name: 1, dtype: object

# %%
d.memory_usage()
# Out:
# Index     132
# name       24
# age        24
# salary     24
# dtype: int64

# %%
d.shape
# Out:
# (3, 3)

# %%
d.dtypes
# Out:
# name      object
# age        int64
# salary     int64
# dtype: object

# %%
d.isnull().sum()
# Out:
# name      0
# age       0
# salary    0
# dtype: int64

# %%
df=pd.read_csv('df.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3671688458.py in <cell line: 0>()
# ----> 1 df=pd.read_csv('df.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df = pd.read_csv("dataclean.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-59379371.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("dataclean.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df = pd.read_csv("C:\Users\tharu\OneDrive\Desktop\sqlproject\dataclean.csv")
# Out:
#   File "/tmp/ipython-input-315418629.py", line 1
#     df = pd.read_csv("C:\Users\tharu\OneDrive\Desktop\sqlproject\dataclean.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
from google.colab import files
import pandas as pd

# Upload the file
uploaded = files.upload()

# After uploading, read it using pandas
df = pd.read_csv("dataclean.csv")
print(df.head())
# Out:
#      <input type="file" id="files-c65a91cf-76de-4d3a-8444-47922c4b3a77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c65a91cf-76de-4d3a-8444-47922c4b3a77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  NORTH     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   EAST      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount  Unnamed: 7 Payment_Method Delivery_Status
# 0        44526.02         NaN            UPI        Canceled
# ...

# %%
df.to_string()
# Out:
# '     Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  Total_Amount  Unnamed: 7 Payment_Method Delivery_Status\n0         31       Pooja T  North        Chair         2    21542.02      44526.02         NaN            UPI        Canceled\n1        173       Pooja M  South   Smartphone         8    30240.21     195127.77         NaN         Online         Pending\n2         85       Priya R   West       Tablet         9     4678.18      33727.96         NaN            NaN       delivered\n3        200       Rahul M   West      Monitor         5    23223.66     124878.89         NaN           Cahs      Delivereed\n4         61       Anita S  NORTH     Keyboard         1    20054.00      21408.64         NaN            NaN         Pending\n5        156     Sneha P    South        Mouse         3     2917.96       9480.88         NaN         Online       delivered\n6         46        Amit K  NORTH        Chair         4    13481.40      58429.15         NaN         Onlin
# ...

# %%
print(df.to_string())
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  Total_Amount  Unnamed: 7 Payment_Method Delivery_Status
# 0         31       Pooja T  North        Chair         2    21542.02      44526.02         NaN            UPI        Canceled
# 1        173       Pooja M  South   Smartphone         8    30240.21     195127.77         NaN         Online         Pending
# 2         85       Priya R   West       Tablet         9     4678.18      33727.96         NaN            NaN       delivered
# 3        200       Rahul M   West      Monitor         5    23223.66     124878.89         NaN           Cahs      Delivereed
# 4         61       Anita S  NORTH     Keyboard         1    20054.00      21408.64         NaN            NaN         Pending
# 5        156     Sneha P    South        Mouse         3     2917.96       9480.88         NaN         Online       delivered
# ...

# %%
df.isnull().sum()
# Out:
# Sale_ID              0
# Customer_Name        0
# Region              30
# Product_Name         0
# Quantity             0
# Unit_Price           0
# Total_Amount         0
# Unnamed: 7         210
# Payment_Method      44
# Delivery_Status     31
# dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['North', 'South', 'West', nan, 'East'], dtype=object)

# %%
df['Region']=df['Region'].replace('NORTH','North')
df['Region']=df['Region'].replace('EAST','East')
df['Region']=df['Region'].replace('west','West')

# %%
df['Region']=df['Region'].replace('nan','South')

# %%
df['Region'].unique()
# Out:
# array(['North', 'South', 'West', nan, 'East'], dtype=object)

# %%
df['Region'].fillna('South',inplace=True)
# Out:
# /tmp/ipython-input-2092082367.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Region'].fillna('South',inplace=True)

# %%
df['Region'].unique()
# Out:
# array(['North', 'South', 'West', nan, 'East'], dtype=object)

# %%
df['Region'].fillna('South', inplace=True)

# %%
df['Region'].unique()
# Out:
# array(['North', 'South', 'West', 'East'], dtype=object)

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount  Unnamed: 7 Payment_Method Delivery_Status
# 0        44526.02         NaN            UPI        Canceled
# ...

# %%
df = df.drop('Unnamed: 7',axis = 1)

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount Payment_Method Delivery_Status
# 0        44526.02            UPI        Canceled
# ...

# %%
df['Payment_Method']= df['Payment_Method'].ffill()

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount Payment_Method Delivery_Status
# 0        44526.02            UPI        Canceled
# ...

# %%
df['Delivery_Status'] = df['Delivery_Status'].bfill()

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount Payment_Method Delivery_Status
# 0        44526.02            UPI        Canceled
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# Length: 210, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# 206       15       Rahul P   West       Tablet         6    38363.03
# 207       93      Manish T  North     Keyboard         2    16411.34
# 208      180        Ravi P   West   Smartwatch         6    43244.79
# 209      103       Priya M  South        Mouse         8     1752.03
#
#      Total_Amount Payment_Method Delivery_Status
# 0        44526.02            UPI        Canceled
# ...

# %%
import numpy as np

cons = [df['Quantity'] >= 8, df['Quantity'] >= 5, df['Quantity'] >= 2]
res = ['A', 'B', 'C']

df['condition'] = np.select(cons, res, default='D')
df
# Out:
# /tmp/ipython-input-3210546806.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['condition'] = np.select(cons, res, default='D')
#      Sale_ID Customer_Name Region Product_Name  Quantity  Unit_Price  \
# 0         31       Pooja T  North        Chair         2    21542.02
# 1        173       Pooja M  South   Smartphone         8    30240.21
# 2         85       Priya R   West       Tablet         9     4678.18
# 3        200       Rahul M   West      Monitor         5    23223.66
# 4         61       Anita S  North     Keyboard         1    20054.00
# ..       ...           ...    ...          ...       ...         ...
# 205      107        Ravi S   East      Printer         7     8132.92
# ...

# %%
print(df.to_csv('mynewdata.csv'))
# Out:
# None
